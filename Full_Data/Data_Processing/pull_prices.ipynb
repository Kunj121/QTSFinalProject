# %%
api = '034270d2-32e5-4068-87d7-aa791e60de38'

# %%
from kunj.data_preparation import *
import kunj.data_preparation as dp

# %%
dot_hourly = dp.fetch_with_fallbacks('DOT', period_id="1HRS", start_date='2020-01-01')
dot_hourly.to_parquet()

# %%
dot_hourly.to_parquet('dot_hourly')

# %%
near_hourly = dp.fetch_with_fallbacks('NEAR', period_id="1HRS", start_date='2020-01-01')

# %%
# eth_hourly = fetch_with_fallbacks("ETH", period_id="1HRS")

# %%
near_hourly.to_csv('near_hourly', index=False)
