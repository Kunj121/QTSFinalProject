# %%
import pm
import matplotlib.pyplot as plt
import sys
from pm import *
import pm as pm
import importlib
importlib.reload(pm)
# Out:
# <module 'pm' from '/Users/tatmaca/uchicago_courses/grad/winter-2024/QTSFinalProject/pm.py'>

# %%
dfs, price_dfs = pm.prep_data()

# %%
print(f"dfs keys: {dfs.keys()}")
print(f"price_dfs keys: {price_dfs.keys()}")
# Out:
# dfs keys: dict_keys(['AVAX', 'NEAR', 'SOL', 'DOT', 'MATIC'])
# price_dfs keys: dict_keys(['AVAX', 'DOT', 'MATIC', 'NEAR', 'SOL'])

# %% [markdown]
# "FINAL MODEL"`

# %%
pm.generate_seaborn_plots(results, pnl, cumulative_capital, price_dfs, stop_loss)

# %%
pm.display_end_pnl_by_coin(results, starting_capital, plot = True)
# Out:
#     Coin Initial Investment  Final Value         PNL  PNL (%)
# 2    SOL         $20,000.00   $27,951.93   $7,951.93   39.76%
# 1   NEAR         $20,000.00   $23,531.94   $3,531.94   17.66%
# 0   AVAX         $20,000.00   $21,158.27   $1,158.27    5.79%
# 3    DOT         $20,000.00   $20,806.55     $806.55    4.03%
# 4  MATIC         $20,000.00   $16,959.74  $-3,040.26  -15.20%
# 5  TOTAL        $100,000.00  $110,408.45  $10,408.45   10.41%

# %%
results['AVAX']
# Out:
#                            Date  Prediction  Probability Buy  \
# 0     2024-07-21 14:00:00+00:00           1         0.250466
# 1     2024-07-21 15:00:00+00:00           1         0.225317
# 2     2024-07-21 16:00:00+00:00           0         0.432665
# 3     2024-07-21 17:00:00+00:00           0         0.416827
# 4     2024-07-21 18:00:00+00:00           0         0.409165
# ...                         ...         ...              ...
# 5059  2025-02-23 19:00:00+00:00           1         0.028991
# 5060  2025-02-23 20:00:00+00:00           1         0.030891
# 5061  2025-02-23 21:00:00+00:00           1         0.029017
# 5062  2025-02-23 22:00:00+00:00           1         0.044766
# 5063  2025-02-23 23:00:00+00:00           1         0.036972
#
#       Probability Sell  Investment  Cash Holdings  Stock Holdings  Coin Value  \
# 0             0.163456    0.000000   20000.000000        0.000000    0.000000
# 1             0.153234    0.000000   20000.000000        0.000000    0.000000
# 2             0.219299   86.533076   19913.380391        2.792290   86.533076
# 3             0.268454   83.365411   19829.931615        5.445550  171.099171
# 4             0.315645   81.833023   19748.016760        8.111989  248.956943
# ...                ...         ...            ...             ...         ...
# 5059          0.165718    0.000000   20943.429477        8.719258  213.970595
# 5060          0.176683    0.000000   20943.429477        8.719258  213.621825
# 5061          0.159265    0.000000   20943.429477        8.719258  215.104099
# 5062          0.170836    0.000000   20943.429477        8.719258  215.627254
# 5063          0.135231    0.000000   20943.429477        8.719258  214.842521
#
#       Total Portfolio Value  Stop Loss Triggered
# 0             100000.000000                False
# 1             100000.000000                False
# 2              99999.913467                False
# 3             100001.030786                False
# 4              99996.973702                False
# ...                     ...                  ...
# 5059          101157.400072                False
# 5060          101157.051302                False
# 5061          101158.533576                False
# 5062          101159.056731                False
# 5063          101158.271998                False
#
# [5064 rows x 10 columns]
