# %%
import pm
import matplotlib.pyplot as plt
import sys
from pm import *
import pm as pm
import importlib
importlib.reload(pm)
# Out:
# <module 'pm' from '/Users/tatmaca/uchicago_courses/grad/winter-2024/QTSFinalProject/pm.py'>

# %%
dfs, price_dfs = pm.prep_data()

# %%
print(f"dfs keys: {dfs.keys()}")
print(f"price_dfs keys: {price_dfs.keys()}")
# Out:
# dfs keys: dict_keys(['AVAX', 'NEAR', 'SOL', 'DOT', 'MATIC'])
# price_dfs keys: dict_keys(['AVAX', 'DOT', 'MATIC', 'NEAR', 'SOL'])

# %% [markdown]
# "FINAL MODEL"`

# %%
stop_loss_pct = 100000000
starting_capital = 100_000
coin_names = coin_names = list(dfs.keys())
portfolio_size = len(coin_names)

results, stop_loss = pm.calculate_investment_portfolio(dfs, price_dfs, starting_capital, portfolio_size, coin_names)

pnl, cumulative_capital = pm.calculate_pnl(results, starting_capital)

plt.figure(figsize=(10, 5))
plt.plot(pnl)
plt.title("Profit and Loss (PNL) Over Time")
plt.xlabel("Time (Trades)")
plt.ylabel("PNL")
plt.grid(True)
plt.show()

# for coin, result_df in results.items():
#     print(f"\n{coin} Results:")
#     display(result_df)

# %%
pm.generate_seaborn_plots(results, pnl, cumulative_capital, price_dfs, stop_loss)

# %%
pm.display_end_pnl_by_coin(results, starting_capital, plot = True)
# Out:
#     Coin Initial Investment Final Value         PNL  PNL (%)
# 3    DOT         $20,000.00  $19,920.12     $-79.88   -0.40%
# 0   AVAX         $20,000.00  $19,849.99    $-150.01   -0.75%
# 1   NEAR         $20,000.00  $19,517.31    $-482.69   -2.41%
# 4  MATIC         $20,000.00  $18,618.68  $-1,381.32   -6.91%
# 2    SOL         $20,000.00  $17,116.69  $-2,883.31  -14.42%
# 5  TOTAL        $100,000.00  $95,022.78  $-4,977.22   -4.98%

# %%
results['AVAX']
# Out:
#       Prediction  Probability Buy  Probability Sell  Investment  \
# 0            1.0         0.210516          0.195172    0.000000
# 1            1.0         0.198007          0.190278    0.000000
# 2            0.0         0.359344          0.346986   71.868706
# 3            2.0         0.342209          0.410304  -71.690876
# 4            2.0         0.304291          0.486052    0.000000
# ...          ...              ...               ...         ...
# 1002         1.0         0.122115          0.181979    0.000000
# 1003         1.0         0.109557          0.166444    0.000000
# 1004         1.0         0.139551          0.210153    0.000000
# 1005         1.0         0.138648          0.224869    0.000000
# 1006         1.0         0.117221          0.192835    0.000000
#
#       Cash Holdings  Stock Holdings  Coin Value  Total Portfolio Value  \
# 0      20000.000000        0.000000    0.000000          100000.000000
# 1      20000.000000        0.000000    0.000000          100000.000000
# 2      19928.059426        2.540428   71.868706           99999.928131
# 3      19999.678610        0.000000    0.000000           99999.678610
# 4      19999.678610        0.000000    0.000000           99999.678610
# ...             ...             ...         ...                    ...
# 1002   19679.140924        7.402289  170.030569           99849.171493
# 1003   19679.140924        7.402289  169.882523           99849.023447
# 1004   19679.140924        7.402289  169.956546           99849.097470
# 1005   19679.140924        7.402289  171.955164           99851.096088
# 1006   19679.140924        7.402289  170.844821           99849.985745
#
#       Stop Loss Triggered
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 1002                False
# 1003                False
# 1004                False
# 1005                False
# 1006                False
#
# [1007 rows x 9 columns]
